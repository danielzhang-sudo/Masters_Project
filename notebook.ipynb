# %%
import pandas as pd

df = pd.read_csv('/content/lending_club_loan_two.csv')

# %%
pd.set_option('display.max_columns', None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264853 entries, 0 to 264852
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             264853 non-null  float64
#  1   term                  264853 non-null  object
#  2   int_rate              264853 non-null  float64
#  3   installment           264853 non-null  float64
#  4   grade                 264853 non-null  object
#  5   sub_grade             264853 non-null  object
#  6   emp_title             249506 non-null  object
#  7   emp_length            252591 non-null  object
#  8   home_ownership        264852 non-null  object
#  9   annual_inc            264852 non-null  float64
#  10  verification_status   264852 non-null  object
#  11  issue_d               264852 non-null  object
#  12  loan_status           264852 non-null  object
#  13  purpose               264852 non-null  object
# ...

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  \
# 0                Marketing  10+ years           RENT    117000.0
# 1          Credit analyst     4 years       MORTGAGE     65000.0
# 2             Statistician   < 1 year           RENT     43057.0
# 3          Client Advocate    6 years           RENT     54000.0
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0
#
#   verification_status   issue_d  loan_status             purpose  \
# 0        Not Verified  Jan-2015   Fully Paid            vacation
# ...

# %%
df.nunique()
# Out:
# loan_amnt                 1381
# term                         2
# int_rate                   560
# installment              47323
# grade                        7
# sub_grade                   35
# emp_title               123159
# emp_length                  11
# home_ownership               6
# annual_inc               19974
# verification_status          3
# issue_d                    115
# loan_status                  2
# purpose                     14
# title                    34673
# dti                       4165
# earliest_cr_line           666
# open_acc                    60
# pub_rec                     19
# revol_bal                49352
# revol_util                1172
# total_acc                  116
# initial_list_status          2
# application_type             3
# mort_acc                    32
# pub_rec_bankruptcies         9
# address                 263733
# dtype: int64

# %%
# discard
# address

# numerical encoding:
# loan_amount, term, int_rate, installment, grade, subgrade, emp_length, home_ownership, annual_inc, verification_status, issue date, purpose, dti, earliest_cr_line, open_acc, pub_rec,
# revol_bal, revol_util, total_acc, initial_list_status, application_type, mort_acc, pub_rec_bankruptcies

# word embedding
# title

# class
# loan_status

# %%
titles = list(df['title'].unique())

# %%
titles
# Out:
# ['Vacation',
#  'Debt consolidation',
#  'Credit card refinancing',
#  'Credit Card Refinance',
#  'Home improvement',
#  'No More Credit Cards',
#  'Debt Consolidation',
#  'Business',
#  'Major purchase',
#  'Debt Consolidation/Home Repairs',
#  'kawasaki jetski',
#  'Medical and Post Graduate Education Expenses',
#  'Credit card debt',
#  'concolidation',
#  'Consolidation Loan',
#  'Consolidate debt',
#  'Pay Off Credit Card',
#  'Cover',
#  'Making a difference',
#  'Debt Consalidation',
#  'Thank you for your help!',
#  'Medical expenses',
#  'debt consolidation',
#  'Other',
#  'Dental Work',
#  'Dept Consolodation/Home Improvement',
#  'Want to be debt free in "3"',
#  'Moving Forward',
#  'Bills',
#  'Honost Consolidation',
#  'home expenses',
#  'Pay the Bills',
#  'Debt Loan',
#  'Car financing',
#  'Moving and relocation',
#  'Home buying',
#  'credit card refinance loan',
#  'Moving Payoff',
#  'Small Business Loan - Gourmet Food Truck',
#  'consolidation loan',
# ...
